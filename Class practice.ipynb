# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.salary.dtype
# Out:
# dtype('int64')

# %%
df['salary'].dtype
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 468

# %%
df.shape
# Out:
# (78, 6)

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
df.sample(7)
# Out:
#         rank discipline  phd  service     sex  salary
# 2       Prof          A   23       20    Male  110515
# 58      Prof          B   36       26  Female  144651
# 0       Prof          B   56       49    Male  186960
# 63      Prof          A   29       27  Female   91000
# 51      Prof          B   20       14  Female  127512
# 55  AsstProf          A    2        0  Female   72500
# 33      Prof          B   18       18    Male  120000

# %%
df_rank = df.groupby(['rank'])

# %%
df_rank

# %%
df_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df_rank = df.groupby('rank')[['salary']].mean()

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df_sub = df[df['salary'] > 120000 & df['sex'] == 'Female']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     273         #  (xint or xbool) and (yint or bool)
# --> 274         result = op(x, y)
#     275     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     287             try:
# --> 288                 result = libops.scalar_binop(x, y, op)
#     289             except (
#
# ...

# %%
df_sub
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df_f = df[df['sex'] == 'Female']

# %%
df_f
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# ...

# %%
df_sub = df[(df['salary'] > 120000) & (df['sex'] == 'Female')]

# %%
df_sub
# Out:
#     rank discipline  phd  service     sex  salary
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# 44  Prof          B   23       19  Female  151768
# 45  Prof          B   25       25  Female  140096
# 49  Prof          B   17       18  Female  122960
# 51  Prof          B   20       14  Female  127512
# 58  Prof          B   36       26  Female  144651
# 72  Prof          B   24       15  Female  161101
# 75  Prof          B   17       17  Female  124312

# %%
df_sub = df[(df['phd'] >= 18) & (df['service'] == 18)]

# %%
df_sub
# Out:
#     rank discipline  phd  service     sex  salary
# 4   Prof          B   20       18    Male  104800
# 7   Prof          A   18       18    Male  126300
# 33  Prof          B   18       18    Male  120000
# 39  Prof          B   18       18  Female  129000

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.loc[20:41,['rank','phd','salary']]
# Out:
#          rank  phd  salary
# 20   AsstProf    4   92000
# 21       Prof   33  103106
# 22   AsstProf    4   73000
# 23   AsstProf    2   85000
# 24       Prof   30   91100
# 25       Prof   35   99418
# 26       Prof   38  148750
# 27       Prof   45  155865
# 28   AsstProf    7   91300
# 29       Prof   21  123683
# 30  AssocProf    9  107008
# 31       Prof   22  155750
# 32       Prof   27  103275
# 33       Prof   18  120000
# 34  AssocProf   12  119800
# 35       Prof   28  126933
# 36       Prof   45  146856
# 37       Prof   20  102000
# 38   AsstProf    4   91000
# 39       Prof   18  129000
# 40       Prof   39  137000
# 41  AssocProf   13   74830

# %%
df.iloc[20:41,[0,2,5]]
# Out:
#          rank  phd  salary
# 20   AsstProf    4   92000
# 21       Prof   33  103106
# 22   AsstProf    4   73000
# 23   AsstProf    2   85000
# 24       Prof   30   91100
# 25       Prof   35   99418
# 26       Prof   38  148750
# 27       Prof   45  155865
# 28   AsstProf    7   91300
# 29       Prof   21  123683
# 30  AssocProf    9  107008
# 31       Prof   22  155750
# 32       Prof   27  103275
# 33       Prof   18  120000
# 34  AssocProf   12  119800
# 35       Prof   28  126933
# 36       Prof   45  146856
# 37       Prof   20  102000
# 38   AsstProf    4   91000
# 39       Prof   18  129000
# 40       Prof   39  137000

# %%
df.iloc[-1]
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
df.tail(1)
# Out:
#     rank discipline  phd  service     sex  salary
# 77  Prof          A   23       15  Female  109646

# %%
df.iloc[[30,70],1:5]
# Out:
#    discipline  phd  service     sex
# 30          B    9        7    Male
# 70          A    8        3  Female

# %%
df.sort_values(by = 'salary',ascending= False).head()
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 72  Prof          B   24       15  Female  161101
# 27  Prof          A   45       43    Male  155865
# 31  Prof          B   22       21    Male  155750

# %%
df.sort_values(by = 'salary').head()
# Out:
#          rank discipline  phd  service     sex  salary
# 9        Prof          A   51       51    Male   57800
# 54  AssocProf          A   25       22  Female   62884
# 66   AsstProf          A    7        6  Female   63100
# 71  AssocProf          B   12        9  Female   71065
# 57   AsstProf          A    3        1  Female   72500

# %%
df.sort_values(by = ['service','salary'],ascending= [True,False]).head(10)
# Out:
#         rank discipline  phd  service     sex  salary
# 52      Prof          A   12        0  Female  105000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 55  AsstProf          A    2        0  Female   72500
# 57  AsstProf          A    3        1  Female   72500
# 28  AsstProf          B    7        2    Male   91300
# 42  AsstProf          B    4        2  Female   80225
# 68  AsstProf          A    4        2  Female   77500

# %%
import pandas as pd
data = pd.read_csv('flights.csv')

# %%
data.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     461    LGA  ATL     116.0       762   5.0    54.0
# 4    1696    EWR  ORD     150.0       719   5.0    54.0

# %%
data.sample(5)
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 21950   2013     10   21    1626.0        6.0    1738.0      -17.0      DL
# 41513   2013     12    5     726.0       -4.0    1006.0      -34.0      AA
# 18699   2013     10   14    1157.0       -3.0    1514.0        8.0      DL
# 151211  2013      9    9     755.0       -5.0     923.0        5.0      US
# 100648  2013      5   19    2128.0       63.0      58.0       78.0      UA
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# 21950   N324NB    2443    JFK  BOS      41.0       187  16.0    26.0
# 41513   N3KBAA      29    LGA  PBI     136.0      1035   7.0    26.0
# 18699   N706TW     423    JFK  LAX     346.0      2475  11.0    57.0
# 151211  N702UW    2171    LGA  DCA      56.0       214   7.0    55.0
# 100648  N518UA     771    JFK  LAX     328.0      2475  21.0    28.0

# %%
data.shape
# Out:
# (160754, 16)

# %%
data.size
# Out:
# 2572064

# %%
data.dtypes
# Out:
# year           int64
# month          int64
# day            int64
# dep_time     float64
# dep_delay    float64
# arr_time     float64
# arr_delay    float64
# carrier       object
# tailnum       object
# flight         int64
# origin        object
# dest          object
# air_time     float64
# distance       int64
# hour         float64
# minute       float64
# dtype: object

# %%
data.groupby('carrier')['dest'].count()
# Out:
# carrier
# AA    32729
# AS      714
# DL    48110
# UA    58665
# US    20536
# Name: dest, dtype: int64

# %%
data.sort_values('distance',ascending=False)
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 38724   2013     11   28     927.0       -3.0    1446.0      -44.0      UA
# 101817  2013      5   22    1331.0        2.0    1819.0        8.0      UA
# 17501   2013     10   11    1324.0       -5.0    1754.0      -19.0      UA
# 27214   2013     11    2    1314.0        4.0    1751.0       -3.0      UA
# 157450  2013      9   23    1353.0       24.0    1815.0        1.0      UA
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 9459    2013      1   24     554.0       -6.0     707.0        9.0      US
# 3290    2013      1    9     554.0       -6.0     642.0      -16.0      US
# 6617    2013      1   17     602.0        2.0     657.0       -1.0      US
# 10341   2013      1   26     603.0        3.0     715.0       17.0      US
# 131783  2013      7   27       NaN        NaN       NaN        NaN      US
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
data.loc[[32,7013,9999],['year','dep_delay','origin','distance']]
# Out:
#       year  dep_delay origin  distance
# 32    2013       -5.0    JFK      2586
# 7013  2013       -1.0    LGA      1035
# 9999  2013       -2.0    JFK      1598

# %%
data[['dep_delay','arr_delay']].agg(['min','mean','max'])
# Out:
#         dep_delay    arr_delay
# min    -33.000000   -75.000000
# mean     9.463773     2.094537
# max   1014.000000  1007.000000

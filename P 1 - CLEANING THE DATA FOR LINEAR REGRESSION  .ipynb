# %%
import pandas as pd

# %%
a = pd.read_csv('loan_small.csv')

# %%
a.isnull().sum()
# Out:
# Loan_ID              0
# Gender               1
# ApplicantIncome      2
# CoapplicantIncome    1
# LoanAmount           3
# Area                 1
# Loan_Status          1
# dtype: int64

# %%
a.isnull().sum(axis = 0)
# Out:
# Loan_ID              0
# Gender               1
# ApplicantIncome      2
# CoapplicantIncome    1
# LoanAmount           3
# Area                 1
# Loan_Status          1
# dtype: int64

# %%
a
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0    NaN
# 3   LP001006  Female           2583.0             2358.0       120.0   semi
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# ...

# %%
a.dropna()
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# 11  LP001027    Male           2500.0             1840.0       109.0  urban
# 13  LP001029    Male           1853.0             2840.0       114.0  urban
# 14  LP001030    Male           1299.0             1086.0        17.0   semi
# 15  LP001032    Male           4950.0                0.0       125.0   semi
#
#    Loan_Status
# 5            Y
# 7            N
# 8            Y
# 9            N
# 10           Y
# 11           Y
# 13           N
# 14           Y
# 15           Y

# %%
a.dropna(subset = ['Loan_Status'])
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0    NaN
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# 11  LP001027    Male           2500.0             1840.0       109.0  urban
# ...

# %%
b = a.copy()
b
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0    NaN
# 3   LP001006  Female           2583.0             2358.0       120.0   semi
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# ...

# %%
cols = ['Gender','Area','Loan_Status']
b[cols] = b[cols].fillna(b.mode().loc[0])
b
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002    Male           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0   semi
# 3   LP001006  Female           2583.0             2358.0       120.0   semi
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# ...

# %%
cols = ['Gender','Area','Loan_Status']

# %%
b[cols].fillna(b.mode().iloc[0])
# Out:
#     Gender   Area Loan_Status
# 0     Male  urban           Y
# 1     Male   semi           N
# 2     Male   semi           Y
# 3   Female   semi           Y
# 4     Male  urban           Y
# 5     Male   semi           Y
# 6     Male  rural           Y
# 7   Female   semi           N
# 8     Male  rural           Y
# 9     Male   semi           N
# 10  Female  urban           Y
# 11    Male  urban           Y
# 12  Female  urban           Y
# 13    Male  urban           N
# 14    Male   semi           Y
# 15    Male   semi           Y

# %%
col2 = ['ApplicantIncome','CoapplicantIncome','LoanAmount']

# %%
a[col2].fillna(a.mean().iloc[0])
# Out:
#     ApplicantIncome  CoapplicantIncome   LoanAmount
# 0       5849.000000           0.000000  4103.571429
# 1       4583.000000        4103.571429   128.000000
# 2       3000.000000           0.000000    66.000000
# 3       2583.000000        2358.000000   120.000000
# 4       4103.571429           0.000000   141.000000
# 5       5417.000000        4196.000000   267.000000
# 6       2333.000000        1516.000000  4103.571429
# 7       3036.000000        2504.000000   158.000000
# 8       4006.000000        1526.000000   168.000000
# 9      12841.000000       10968.000000   349.000000
# 10      3200.000000         700.000000    70.000000
# 11      2500.000000        1840.000000   109.000000
# 12      4103.571429        8106.000000  4103.571429
# 13      1853.000000        2840.000000   114.000000
# 14      1299.000000        1086.000000    17.000000
# 15      4950.000000           0.000000   125.000000

# %%
import pandas as pd
a = pd.read_csv('loan_small.csv')
a = a.dropna()
a
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# 11  LP001027    Male           2500.0             1840.0       109.0  urban
# 13  LP001029    Male           1853.0             2840.0       114.0  urban
# 14  LP001030    Male           1299.0             1086.0        17.0   semi
# 15  LP001032    Male           4950.0                0.0       125.0   semi
#
#    Loan_Status
# 5            Y
# 7            N
# 8            Y
# 9            N
# 10           Y
# 11           Y
# 13           N
# 14           Y
# 15           Y

# %%
col = ['Gender','Area','Loan_Status']
a[col] = a[col].astype('category')
for i in col:
    a[i] = a[i].cat.codes
a
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount  Area  \
# 5   LP001011       1           5417.0             4196.0       267.0     1
# 7   LP001014       0           3036.0             2504.0       158.0     1
# 8   LP001018       1           4006.0             1526.0       168.0     0
# 9   LP001020       1          12841.0            10968.0       349.0     1
# 10  LP001024       0           3200.0              700.0        70.0     2
# 11  LP001027       1           2500.0             1840.0       109.0     2
# 13  LP001029       1           1853.0             2840.0       114.0     2
# 14  LP001030       1           1299.0             1086.0        17.0     1
# 15  LP001032       1           4950.0                0.0       125.0     1
#
#     Loan_Status
# 5             1
# 7             0
# 8             1
# 9             0
# 10            1
# 11            1
# 13            0
# 14            1
# 15            1

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
a = pd.read_csv('loan_small.csv')
a = a.dropna()
a.drop(['Loan_ID','Gender','Area','Loan_Status'], axis = 1,inplace = True)
a
# Out:
#     ApplicantIncome  CoapplicantIncome  LoanAmount
# 5            5417.0             4196.0       267.0
# 7            3036.0             2504.0       158.0
# 8            4006.0             1526.0       168.0
# 9           12841.0            10968.0       349.0
# 10           3200.0              700.0        70.0
# 11           2500.0             1840.0       109.0
# 13           1853.0             2840.0       114.0
# 14           1299.0             1086.0        17.0
# 15           4950.0                0.0       125.0

# %%
(5417.0 - a['ApplicantIncome'].min())/(a['ApplicantIncome'].max() - a['ApplicantIncome'].min())
# Out:
# 0.35678391959798994

# %%
b = a.iloc[:,2:5]
b
# Out:
#     LoanAmount
# 5        267.0
# 7        158.0
# 8        168.0
# 9        349.0
# 10        70.0
# 11       109.0
# 13       114.0
# 14        17.0
# 15       125.0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(b)
# Out:
# array([[ 1.1995349 ],
#        [ 0.05261118],
#        [ 0.15783354],
#        [ 2.06235824],
#        [-0.87334558],
#        [-0.46297838],
#        [-0.4103672 ],
#        [-1.43102409],
#        [-0.29462261]])

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
a = pd.read_csv('loan_small.csv')
a = a.dropna()
a.drop(['Loan_ID','Gender','Area','Loan_Status'], axis = 1,inplace = True)
from sklearn.preprocessing import minmax_scale

# %%
b = minmax_scale(a)

# %%
b
# Out:
# array([[0.35678392, 0.38256747, 0.75301205],
#        [0.15049385, 0.22830051, 0.4246988 ],
#        [0.23453474, 0.13913202, 0.45481928],
#        [1.        , 1.        , 1.        ],
#        [0.16470282, 0.06382203, 0.15963855],
#        [0.10405476, 0.16776076, 0.27710843],
#        [0.04799861, 0.25893508, 0.29216867],
#        [0.        , 0.09901532, 0.        ],
#        [0.31632299, 0.        , 0.3253012 ]])

# %%
import pandas as pd
s = pd.read_csv('Loan_small.csv')

# %%
a = s.dropna(subset = ['Loan_Status'])

# %%
col = ['Gender','Area','Loan_Status']
a[col] = a[col].fillna(a.mode().iloc[0])
a
# Out:
# C:\Users\HARI KRISHNA\anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002    Male           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0   semi
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# ...

# %%
col2 = ['ApplicantIncome','CoapplicantIncome','LoanAmount']
a[col2] = a[col2].fillna(a.mean().iloc[0])
a
# Out:
# C:\Users\HARI KRISHNA\anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome   LoanAmount   Area  \
# 0   LP001002    Male      5849.000000           0.000000  4220.538462  urban
# 1   LP001003    Male      4583.000000        4220.538462   128.000000   semi
# 2   LP001005    Male      3000.000000           0.000000    66.000000   semi
# 4   LP001008    Male      4220.538462           0.000000   141.000000  urban
# 5   LP001011    Male      5417.000000        4196.000000   267.000000   semi
# 6   LP001013    Male      2333.000000        1516.000000  4220.538462  rural
# ...

# %%
a = a.drop(['Loan_ID'], axis = 1)
a.describe(dtypes())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-88aa0be23555> in <module>
# ----> 1 a = a.drop(['Loan_ID'], axis = 1)
#       2 a.describe(dtypes())
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
b = pd.get_dummies(a, drop_first = True )
b
# Out:
#     ApplicantIncome  CoapplicantIncome   LoanAmount  Gender_Male  Area_semi  \
# 0       5849.000000           0.000000  4220.538462            1          0
# 1       4583.000000        4220.538462   128.000000            1          1
# 2       3000.000000           0.000000    66.000000            1          1
# 4       4220.538462           0.000000   141.000000            1          0
# 5       5417.000000        4196.000000   267.000000            1          1
# 6       2333.000000        1516.000000  4220.538462            1          0
# 7       3036.000000        2504.000000   158.000000            0          1
# 8       4006.000000        1526.000000   168.000000            1          0
# 9      12841.000000       10968.000000   349.000000            1          1
# 10      3200.000000         700.000000    70.000000            0          0
# 11      2500.000000        1840.000000   109.000000            1          0
# ...

# %%
x = b.iloc[:,:-1]
y = b.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest,ytrain, ytest = train_test_split( x, y,test_size = 0.2, random_state = 1234)

# %%
xtrain
# Out:
#     ApplicantIncome  CoapplicantIncome   LoanAmount  Gender_Male  Area_semi  \
# 13      1853.000000        2840.000000   114.000000            1          0
# 15      4950.000000           0.000000   125.000000            1          1
# 2       3000.000000           0.000000    66.000000            1          1
# 11      2500.000000        1840.000000   109.000000            1          0
# 8       4006.000000        1526.000000   168.000000            1          0
# 1       4583.000000        4220.538462   128.000000            1          1
# 10      3200.000000         700.000000    70.000000            0          0
# 9      12841.000000       10968.000000   349.000000            1          1
# 5       5417.000000        4196.000000   267.000000            1          1
# 6       2333.000000        1516.000000  4220.538462            1          0
# 7       3036.000000        2504.000000   158.000000            0          1
# ...

# %%
xtest
# Out:
#     ApplicantIncome  CoapplicantIncome   LoanAmount  Gender_Male  Area_semi  \
# 14      1299.000000             1086.0    17.000000            1          1
# 12      4220.538462             8106.0  4220.538462            0          0
# 0       5849.000000                0.0  4220.538462            1          0
#
#     Area_urban
# 14           0
# 12           1
# 0            1

# %%
ytrain
# Out:
# 13    0
# 15    1
# 2     1
# 11    1
# 8     1
# 1     0
# 10    1
# 9     0
# 5     1
# 6     1
# 7     0
# 4     1
# Name: Loan_Status_Y, dtype: uint8

# %%
ytest
# Out:
# 14    1
# 12    1
# 0     1
# Name: Loan_Status_Y, dtype: uint8

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('world_alchol.csv')

# %%
data
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %%
data.iloc[0:2,1:2]
# Out:
#         WHO region
# 0  Western Pacific
# 1         Americas

# %%
data.sample(frac = 0.)
# Out:
#     Year             WHO region  \
# 8   1986               Americas
# 53  1984  Eastern Mediterranean
# 26  1985                 Europe
# 78  1989               Americas
# 50  1985                 Europe
# 61  1984        Western Pacific
# 33  1985                 Africa
# 10  1987                 Africa
# 47  1986               Americas
# 37  1986                 Europe
#
#                                               Country Beverage Types  \
# 8                                 Antigua and Barbuda        Spirits
# 53                                             Kuwait           Beer
# 26  United Kingdom of Great Britain and Northern I...           Wine
# 78                                            Jamaica          Other
# 50                                        Switzerland          Other
# 61                                   Papua New Guinea        Spirits
# 33                                         Mauritania          Other
# ...

# %%
data.dropna()
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %%
data[data['WHO region'] == 'Western Pacific']
# Out:
#     Year       WHO region                           Country Beverage Types  \
# 0   1986  Western Pacific                          Viet Nam           Wine
# 12  1985  Western Pacific  Lao People's Democratic Republic           Beer
# 14  1985  Western Pacific                          Viet Nam        Spirits
# 28  1987  Western Pacific                          Viet Nam           Beer
# 31  1986  Western Pacific  Micronesia (Federated States of)           Wine
# 43  1984  Western Pacific                             China           Wine
# 56  1987  Western Pacific                          Viet Nam           Wine
# 61  1984  Western Pacific                  Papua New Guinea        Spirits
#
#     Display Value
# 0            0.00
# 12           0.00
# 14           0.05
# 28           0.11
# 31           0.00
# 43           0.03
# 56           0.00
# 61           0.08

# %%
data.drop_duplicates('WHO region')
# Out:
#     Year             WHO region       Country Beverage Types  Display Value
# 0   1986        Western Pacific      Viet Nam           Wine           0.00
# 1   1986               Americas       Uruguay          Other           0.50
# 2   1985                 Africa  Cte d'Ivoire           Wine           1.62
# 13  1984  Eastern Mediterranean   Afghanistan          Other           0.00
# 18  1984                 Europe        Norway        Spirits           1.62
# 20  1986        South-East Asia       Myanmar           Wine           0.00

# %%
data
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %%
data[data['Year'] == 1985].head(10)
# Out:
#     Year       WHO region                                            Country  \
# 2   1985           Africa                                       Cte d'Ivoire
# 7   1985           Africa                                             Angola
# 12  1985  Western Pacific                   Lao People's Democratic Republic
# 14  1985  Western Pacific                                           Viet Nam
# 24  1985           Africa                                            Comoros
# 26  1985           Europe  United Kingdom of Great Britain and Northern I...
# 33  1985           Africa                                         Mauritania
# 35  1985         Americas                              Saint Kitts and Nevis
# 44  1985           Europe                                          Lithuania
# 50  1985           Europe                                        Switzerland
#
#    Beverage Types  Display Value
# 2            Wine           1.62
# 7         Spirits           0.39
# ...

# %%
data
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %%
data[(data['Year'] == 1987) | (data['Year'] == 1989)]
# Out:
#     Year             WHO region                           Country  \
# 4   1987               Americas             Saint Kitts and Nevis
# 5   1987               Americas                         Guatemala
# 6   1987                 Africa                         Mauritius
# 10  1987                 Africa                          Botswana
# 11  1989               Americas                         Guatemala
# 15  1987                 Africa                     Guinea-Bissau
# 17  1989                 Africa                        Seychelles
# 21  1989               Americas                        Costa Rica
# 28  1987        Western Pacific                          Viet Nam
# 32  1989                 Africa                         Mauritius
# 36  1987  Eastern Mediterranean                             Egypt
# 38  1987  Eastern Mediterranean                             Qatar
# 39  1987                 Africa                      Burkina Faso
# ...

# %%
data
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %%
data[(data['WHO region'] == 'Americas') & (data['Year'] == 1985)]
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 35  1985   Americas  Saint Kitts and Nevis        Spirits           2.24

# %%
data
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %%
data[(data['Year'] == 1986) & (data['WHO region'] == 'Western Pacific')]
# Out:
#     Year       WHO region                           Country Beverage Types  \
# 0   1986  Western Pacific                          Viet Nam           Wine
# 31  1986  Western Pacific  Micronesia (Federated States of)           Wine
#
#     Display Value
# 0             0.0
# 31            0.0

# %%
data[(data['Year'] == 1986) & (data['WHO region'] == 'Western Pacific') & (data['Country'] == 'Viet Nam')]
# Out:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0

# %%
data[((data['Year'] == 1986) | (data['Year'] == 1989)) & ((data['WHO region'] == 'Americas') | (data['WHO region'] == 'Europe'))][['Year','WHO region','Beverage Types']]
# Out:
#     Year WHO region Beverage Types
# 1   1986   Americas          Other
# 3   1986   Americas           Beer
# 8   1986   Americas        Spirits
# 11  1989   Americas           Beer
# 21  1989   Americas        Spirits
# 29  1986     Europe          Other
# 34  1986     Europe           Wine
# 37  1986     Europe           Beer
# 41  1986     Europe           Beer
# 47  1986   Americas          Other
# 49  1986     Europe           Wine
# 55  1989   Americas           Wine
# 57  1989     Europe           Wine
# 64  1989   Americas           Beer
# 74  1986   Americas        Spirits
# 78  1989   Americas          Other
# 79  1989     Europe          Other
# 83  1986     Europe          Other
# 86  1986   Americas           Wine
# 91  1989     Europe           Beer

# %%
data[data['WHO region'].str.contains('Ea')]
# Out:
#     Year             WHO region                                Country  \
# 13  1984  Eastern Mediterranean                            Afghanistan
# 20  1986        South-East Asia                                Myanmar
# 25  1984  Eastern Mediterranean                                Tunisia
# 27  1984  Eastern Mediterranean                                Bahrain
# 36  1987  Eastern Mediterranean                                  Egypt
# 38  1987  Eastern Mediterranean                                  Qatar
# 52  1986  Eastern Mediterranean                           Saudi Arabia
# 53  1984  Eastern Mediterranean                                 Kuwait
# 58  1984  Eastern Mediterranean                                Somalia
# 59  1989  Eastern Mediterranean                   Syrian Arab Republic
# 60  1987  Eastern Mediterranean             Iran (Islamic Republic of)
# 63  1985  Eastern Mediterranean                                  Libya
# ...

# %%
data[data['WHO region'].isin(["Africa", "Eastern Mediterranean", "Europe"])]
# Out:
#     Year WHO region            Country Beverage Types  Display Value
# 2   1985     Africa       Cte d'Ivoire           Wine           1.62
# 6   1987     Africa          Mauritius           Wine           0.13
# 7   1985     Africa             Angola        Spirits           0.39
# 9   1984     Africa            Nigeria          Other           6.10
# 10  1987     Africa           Botswana           Wine           0.20
# ..   ...        ...                ...            ...            ...
# 93  1987     Africa         Madagascar          Other            NaN
# 94  1985     Europe            Ukraine        Spirits           3.06
# 95  1984     Africa              Niger          Other           0.00
# 96  1985     Europe         Luxembourg           Wine           7.38
# 98  1984     Africa  Equatorial Guinea           Wine           0.00
#
# [69 rows x 5 columns]

# %%
data[(data['Display Value'] > 0.5) & (data['Display Value'] < 2.5)].head()
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 2   1985     Africa           Cte d'Ivoire           Wine           1.62
# 4   1987   Americas  Saint Kitts and Nevis           Beer           1.98
# 8   1986   Americas    Antigua and Barbuda        Spirits           1.55
# 11  1989   Americas              Guatemala           Beer           0.62
# 17  1989     Africa             Seychelles           Beer           2.23

# %%
data.filter()
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# ...
